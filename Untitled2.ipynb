# %%
import pandas as pd
import numpy as np
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import silhouette_score
from sklearn.metrics import r2_score, mean_squared_error
import math

# %%
realreal=pd.read_csv('ข้อมูลจริงหลังจัดกลุ่ม.csv')

# %%
group0_product_value = realreal.loc[realreal['cluster'] == 0, 'มูลค่า(ล้านบาท)'].copy()
group0_product_areap = realreal.loc[realreal['cluster'] == 0, 'เนื้อที่เพาะปลูก(ไร่)'].copy()
group0_product_areah = realreal.loc[realreal['cluster'] == 0, 'เนื้อที่เก็บเกี่ยว(ไร่)'].copy()
group0_product = realreal.loc[realreal['cluster'] == 0, 'ผลผลิต(ตัน)'].copy()

# %%
group1_product_value = realreal.loc[realreal['cluster'] == 1, 'มูลค่า(ล้านบาท)'].copy()
group1_product_areap = realreal.loc[realreal['cluster'] == 1, 'เนื้อที่เพาะปลูก(ไร่)'].copy()
group1_product_areah = realreal.loc[realreal['cluster'] == 1, 'เนื้อที่เก็บเกี่ยว(ไร่)'].copy()
group1_product = realreal.loc[realreal['cluster'] == 1, 'ผลผลิต(ตัน)'].copy()

# %%
group2_product_value = realreal.loc[realreal['cluster'] == 2, 'มูลค่า(ล้านบาท)'].copy()
group2_product_areap = realreal.loc[realreal['cluster'] == 2, 'เนื้อที่เพาะปลูก(ไร่)'].copy()
group2_product_areah = realreal.loc[realreal['cluster'] == 2, 'เนื้อที่เก็บเกี่ยว(ไร่)'].copy()
group2_product = realreal.loc[realreal['cluster'] == 2, 'ผลผลิต(ตัน)'].copy()

# %%
group0_1 = np.mean(group0_product_value)
group0_2 = np.mean(group0_product_areap)
group0_3 = np.mean(group0_product_areah)
group0_4 = np.mean(group0_product)

# %%
group1_1 = np.mean(group1_product_value)
group1_2 = np.mean(group1_product_areap)
group1_3 = np.mean(group1_product_areah)
group1_4 = np.mean(group1_product)

# %%
group2_1 = np.mean(group2_product_value)
group2_2 = np.mean(group2_product_areap)
group2_3 = np.mean(group2_product_areah)
group2_4 = np.mean(group2_product)

# %%
D_1=[group0_1,group0_2,group0_3,group0_4,]
D_2=[group1_1,group1_2,group1_3,group1_4,]
D_3=[group2_1,group2_2,group2_3,group2_4,]

D_1 = np.concatenate((D_1,[D_1[0]]))
D_2 = np.concatenate((D_2,[D_1[0]]))
D_3 = np.concatenate((D_3,[D_3[0]]))

# %%
angles = np.linspace(0, 2 * np.pi, N, endpoint=False).tolist()
angles=np.concatenate((angles,[angles[0]]))

# %%
categories = ['มูลค่า(ล้านบาท)', 'เนื้อที่เพาะปลูก(ไร่)', 'เนื้อที่เก็บเกี่ยว(ไร่)','ผลผลิต(ตัน)']
N = len(categories)
# ค่าเฉลี่ยของมูลค่าสินค้าสำหรับแต่ละกลุ่ม
averages_value = sum([group0_1, group1_1, group2_1])/3
averages_areap=sum([group0_2, group1_2, group2_2])/3
averages_areah=sum([group0_3, group1_3, group2_3])/3
averages_product=sum([group0_4, group1_4, group2_4])/3

fig, ax = plt.subplots(figsize=(8, 8), subplot_kw=dict(polar=True))
# พล็อต radar chart สำหรับแต่ละ cluster
ax.plot(angles, D_1, label='cluster1')
ax.fill(angles, D_1, alpha=0.1)

ax.plot(angles, D_2, label='cluster2')
ax.fill(angles, D_2, alpha=0.1)

ax.plot(angles, D_3, label='cluster3')
ax.fill(angles, D_3, alpha=0.1)

plt.title('ชื่อของ Radar Chart')
# เพิ่มเลเจนด์
plt.legend(loc='upper right')

# แสดง radar chart
plt.show()
# Out:
# C:\Users\ADMIN\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 3594 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\ADMIN\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 3639 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\ADMIN\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 3656 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\ADMIN\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 3629 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\ADMIN\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 3586 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# ...

# %%
์
# Out:
#   File "<ipython-input-197-b649e8b8bf64>", line 1
#     ์
#     ^
# SyntaxError: invalid character in identifier

# %%
# ***** to close the radar shape add the first list element to the end of the list or concatenate *****
D_1 = np.concatenate((D_1,[D_1[0]]))
D_2 = np.concatenate((D_2,[D_2[0]]))
D_3 = np.concatenate((D_3,[D_3[0]]))
print(D_1)
# Out:
# [  2242.6124778 105658.04       92969.22       26750.78
#    2242.6124778]

# %%
C_1={'Cluster': ['Cluster1', 'Cluster 2', 'Cluster 3'],
     'มูลค่า(ล้านบาท)':[group0_1,group1_1,group2_1],
     'เนื้อที่เพาะปลูก(ไร่)':[group0_2,group1_2,group2_2],
     'เนื้อที่เก็บเกี่ยว(ไร่)':[group0_3,group1_3,group2_3],
     'ผลผลิต(ตัน)':[group0_4,group1_4,group2_4],
    }
CF1=pd.DataFrame(C_1)
CF1
# Out:
#      Cluster  มูลค่า(ล้านบาท)  เนื้อที่เพาะปลูก(ไร่)  เนื้อที่เก็บเกี่ยว(ไร่)  \
# 0   Cluster1      2242.612478          105658.040000                92969.220
# 1  Cluster 2      2095.928797          169207.741935               152942.000
# 2  Cluster 3      1832.273093          134791.700000               121880.875
#
#     ผลผลิต(ตัน)
# 0  26750.780000
# 1  35578.354839
# 2  30495.150000

# %%
categories = ['มูลค่า(ล้านบาท)', 'เนื้อที่เพาะปลูก(ไร่)', 'เนื้อที่เก็บเกี่ยว(ไร่)','ผลผลิต(ตัน)']
N = len(categories)
# กำหนดขนาดของกราฟ
fig, ax = plt.subplots(figsize=(6, 6), subplot_kw=dict(polar=True))
# สร้างเส้นที่เชื่อมกันระหว่างจุด
angles = [n / float(N) * 2 * np.pi for n in range(N)]
D_1 += D_1[:1]
D_2 += D_2[:1]
D_3 += D_3[:1]
angles += angles[:1]

# %%
for i, row in CF1.iterrows():
    values = row.drop('Cluster').values.flatten().tolist()
    values += values[:1]
    ax.plot(angles, values, linewidth=1, linestyle='solid', label=row['Cluster'])
    ax.fill(angles, values, alpha=0.1)

# %%
# สร้าง Radar Chart
ax.plot(angles, D_1, linewidth=1, linestyle='solid', label='Group 1')
ax.fill(angles, D_1, 'b', alpha=0.1)

ax.plot(angles, D_2, linewidth=1, linestyle='solid', label='Group 2')
ax.fill(angles, D_2, 'r', alpha=0.1)

ax.plot(angles, D_3, linewidth=1, linestyle='solid', label='Group 3')
ax.fill(angles, D_3, 'g', alpha=0.1)

# %%
# กำหนดข้อความบนกราฟ
plt.title('Attribute Comparison')
ax.set_theta_offset(np.pi / 2)
ax.set_theta_direction(-1)
ax.set_thetagrids(np.degrees(angles), categories)
ax.yaxis.grid(True)
ax.legend(loc='upper right', bbox_to_anchor=(0.1, 0.1))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-170-94e74265c644> in <module>
#       3 ax.set_theta_offset(np.pi / 2)
#       4 ax.set_theta_direction(-1)
# ----> 5 ax.set_thetagrids(np.degrees(angles), categories)
#       6 ax.yaxis.grid(True)
#       7 ax.legend(loc='upper right', bbox_to_anchor=(0.1, 0.1))
#
# ~\anaconda3\lib\site-packages\matplotlib\projections\polar.py in set_thetagrids(self, angles, labels, fmt, **kwargs)
#    1344         self.set_xticks(angles)
#    1345         if labels is not None:
# -> 1346             self.set_xticklabels(labels)
#    1347         elif fmt is not None:
#    1348             self.xaxis.set_major_formatter(mticker.FormatStrFormatter(fmt))
#
# ~\anaconda3\lib\site-packages\matplotlib\axes\_base.py in wrapper(self, *args, **kwargs)
#      61
#      62         def wrapper(self, *args, **kwargs):
# ...

# %%
# สร้างเส้นที่เชื่อมกันระหว่างจุด
angles = [n / float(N) * 2 * np.pi for n in range(N)]
values_group1 += values_group1[:1]
values_group2 += values_group2[:1]
values_group3 += values_group3[:1]
angles += angles[:1]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-93-eba9030d033f> in <module>
#       1 # สร้างเส้นที่เชื่อมกันระหว่างจุด
#       2 angles = [n / float(N) * 2 * np.pi for n in range(N)]
# ----> 3 values_group1 += values_group1[:1]
#       4 values_group2 += values_group2[:1]
#       5 values_group3 += values_group3[:1]
#
# NameError: name 'values_group1' is not defined

# %%
# กำหนดขนาดของกราฟ
fig, ax = plt.subplots(figsize=(6, 6), subplot_kw=dict(polar=True))
categories = ['มูลค่า(ล้านบาท)', 'เนื้อที่เพาะปลูก(ไร่)', 'เนื้อที่เก็บเกี่ยว(ไร่)','ผลผลิต(ตัน)']
N = len(categories)

# %%
label_placement = np.linspace(start=0, stop=2*np.pi, num=len(D_1))
label_placement
# Out:
# array([0.        , 3.14159265, 6.28318531])

# %%
# create matplotlib figure and polar plot with labels, title, and legend
plt.figure(figsize=(6,6))
plt.subplot(polar=True)
plt.plot(label_placement, D_1)

# %%
# create matplotlib figure and polar plot with labels, title, and legend
plt.figure(figsize=(6,6))
plt.subplot(polar=True)
plt.plot(label_placement, D_1)
# plt.fill(label_placement, vehicle1, 'blue', alpha=0.1)
plt.plot(label_placement, D_2)
plt.plot(label_placement, D_3)
plt.fill(label_placement, D_1, 'blue', alpha=0.1)
plt.fill(label_placement, D_2, 'green', alpha=0.1)
plt.fill(label_placement, D_3, 'red', alpha=0.1)
# use thetagrids to place labels at the specified angles using degrees
lines, labels = plt.thetagrids(np.degrees(label_placement), labels=categories)
plt.title('Compare ', y=1.1, fontdict={'fontsize': 18})
plt.legend(labels=['cluster1','cluster2', 'cluster3'],loc=(0.95, 0.8));
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-57-fca390cf62df> in <module>
#      10 plt.fill(label_placement, D_3, 'red', alpha=0.1)
#      11 # use thetagrids to place labels at the specified angles using degrees
# ---> 12 lines, labels = plt.thetagrids(np.degrees(label_placement), labels=categories)
#      13 plt.title('Compare ', y=1.1, fontdict={'fontsize': 18})
#      14 plt.legend(labels=['cluster1','cluster2', 'cluster3'],loc=(0.95, 0.8));
#
# ~\anaconda3\lib\site-packages\matplotlib\pyplot.py in thetagrids(angles, labels, fmt, **kwargs)
#    1858         labels = ax.xaxis.get_ticklabels()
#    1859     else:
# -> 1860         lines, labels = ax.set_thetagrids(angles,
#    1861                                           labels=labels, fmt=fmt, **kwargs)
#    1862     return lines, labels
#
# ...
